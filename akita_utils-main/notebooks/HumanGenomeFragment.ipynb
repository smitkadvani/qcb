# %%
import matplotlib.pyplot as plt
import bioframe 
import pandas as pd
import numpy as np 
import os
import json
from io import StringIO

# %%
import sys

sys.path.insert(0, "/home1/smaruj/akita_utils/")

from akita_utils import *

# %%
import pysam
import h5py

# %%
genome_open = pysam.Fastafile("/home1/smaruj/hg38.fa")

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import tensorflow as tf
print("Tensorflow: ", tf.__version__)

from basenji import dataset, seqnn, dna_io, stream
# Out:
# Tensorflow:  2.9.1

# %%
# NOTE
# head_i = 0 #human
# head_i = 1 #mouse
#

head_i = 0 #mouse
# head_i = 0  # human
model_num = 1 #which fold to use


#base_dir = '/project/fudenber_735/backup/DNN_HiC/human-mouse_5-16-21/'
#model_dir = base_dir+"/f"+str(model_num)+"_c0/train/"

base_dir = "/project/fudenber_735/tensorflow_models/akita/v2/models/"
model_dir = base_dir + "/f" + str(model_num) + "c0/train/"
model_file  = model_dir + "/model" + str(head_i) + "_best.h5"


# model_dir = '/home1/fudenber/repositories/basenji/manuscripts/akita/'
# model_file = model_dir+'/model_best.h5'

params_file = model_dir + "/params.json"
# params_file -> json (dict) with model's parameters
with open(params_file) as params_open:
    params = json.load(params_open)
    params_model = params["model"]
    params_train = params["train"]
seq_length = params_model["seq_length"]
params_model["verbose"] = False

seqnn_model = seqnn.SeqNN(params_model)
print("built")

seqnn_model.restore(model_file, head_i=head_i)    # model with the mouse head
print("restored")
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  sequence (InputLayer)          [(None, 1310720, 4)  0           []
#                                 ]
#
#  stochastic_reverse_complement_  ((None, 1310720, 4)  0          ['sequence[0][0]']
#  2 (StochasticReverseComplement  , ())
#  )
#
#  stochastic_shift_2 (Stochastic  (None, 1310720, 4)  0           ['stochastic_reverse_complement_2
#  Shift)                                                          [0][0]']
#
#  re_lu_98 (ReLU)                (None, 1310720, 4)   0           ['stochastic_shift_2[0][0]']
#
#  conv1d_68 (Conv1D)             (None, 1310720, 128  7680        ['re_lu_98[0][0]']
#                                 )
#
#  batch_normalization_94 (BatchN  (None, 1310720, 128  512        ['conv1d_68[0][0]']
#  ormalization)                  )
#
#  max_pooling1d_22 (MaxPooling1D  (None, 655360, 128)  0          ['batch_normalization_94[0][0]']
#  )
#
#  re_lu_99 (ReLU)                (None, 655360, 128)  0           ['max_pooling1d_22[0][0]']
#
#  conv1d_69 (Conv1D)             (None, 655360, 128)  81920       ['re_lu_99[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 655360, 128)  512        ['conv1d_69[0][0]']
#  ormalization)
#
#  max_pooling1d_23 (MaxPooling1D  (None, 327680, 128)  0          ['batch_normalization_95[0][0]']
#  )
#
#  re_lu_100 (ReLU)               (None, 327680, 128)  0           ['max_pooling1d_23[0][0]']
#
#  conv1d_70 (Conv1D)             (None, 327680, 128)  81920       ['re_lu_100[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 327680, 128)  512        ['conv1d_70[0][0]']
#  ormalization)
#
#  max_pooling1d_24 (MaxPooling1D  (None, 163840, 128)  0          ['batch_normalization_96[0][0]']
#  )
#
#  re_lu_101 (ReLU)               (None, 163840, 128)  0           ['max_pooling1d_24[0][0]']
#
#  conv1d_71 (Conv1D)             (None, 163840, 128)  81920       ['re_lu_101[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 163840, 128)  512        ['conv1d_71[0][0]']
#  ormalization)
#
#  max_pooling1d_25 (MaxPooling1D  (None, 81920, 128)  0           ['batch_normalization_97[0][0]']
#  )
#
#  re_lu_102 (ReLU)               (None, 81920, 128)   0           ['max_pooling1d_25[0][0]']
#
#  conv1d_72 (Conv1D)             (None, 81920, 128)   81920       ['re_lu_102[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 81920, 128)  512         ['conv1d_72[0][0]']
#  ormalization)
#
#  max_pooling1d_26 (MaxPooling1D  (None, 40960, 128)  0           ['batch_normalization_98[0][0]']
#  )
#
#  re_lu_103 (ReLU)               (None, 40960, 128)   0           ['max_pooling1d_26[0][0]']
#
#  conv1d_73 (Conv1D)             (None, 40960, 128)   81920       ['re_lu_103[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 40960, 128)  512         ['conv1d_73[0][0]']
#  ormalization)
#
#  max_pooling1d_27 (MaxPooling1D  (None, 20480, 128)  0           ['batch_normalization_99[0][0]']
#  )
#
#  re_lu_104 (ReLU)               (None, 20480, 128)   0           ['max_pooling1d_27[0][0]']
#
#  conv1d_74 (Conv1D)             (None, 20480, 128)   81920       ['re_lu_104[0][0]']
#
#  batch_normalization_100 (Batch  (None, 20480, 128)  512         ['conv1d_74[0][0]']
#  Normalization)
#
#  max_pooling1d_28 (MaxPooling1D  (None, 10240, 128)  0           ['batch_normalization_100[0][0]']
#  )
#
#  re_lu_105 (ReLU)               (None, 10240, 128)   0           ['max_pooling1d_28[0][0]']
#
#  conv1d_75 (Conv1D)             (None, 10240, 128)   81920       ['re_lu_105[0][0]']
#
#  batch_normalization_101 (Batch  (None, 10240, 128)  512         ['conv1d_75[0][0]']
#  Normalization)
#
#  max_pooling1d_29 (MaxPooling1D  (None, 5120, 128)   0           ['batch_normalization_101[0][0]']
#  )
#
#  re_lu_106 (ReLU)               (None, 5120, 128)    0           ['max_pooling1d_29[0][0]']
#
#  conv1d_76 (Conv1D)             (None, 5120, 128)    81920       ['re_lu_106[0][0]']
#
#  batch_normalization_102 (Batch  (None, 5120, 128)   512         ['conv1d_76[0][0]']
#  Normalization)
#
#  max_pooling1d_30 (MaxPooling1D  (None, 2560, 128)   0           ['batch_normalization_102[0][0]']
#  )
#
#  re_lu_107 (ReLU)               (None, 2560, 128)    0           ['max_pooling1d_30[0][0]']
#
#  conv1d_77 (Conv1D)             (None, 2560, 128)    81920       ['re_lu_107[0][0]']
#
#  batch_normalization_103 (Batch  (None, 2560, 128)   512         ['conv1d_77[0][0]']
#  Normalization)
#
#  max_pooling1d_31 (MaxPooling1D  (None, 1280, 128)   0           ['batch_normalization_103[0][0]']
#  )
#
#  re_lu_108 (ReLU)               (None, 1280, 128)    0           ['max_pooling1d_31[0][0]']
#
#  conv1d_78 (Conv1D)             (None, 1280, 128)    81920       ['re_lu_108[0][0]']
#
#  batch_normalization_104 (Batch  (None, 1280, 128)   512         ['conv1d_78[0][0]']
#  Normalization)
#
#  max_pooling1d_32 (MaxPooling1D  (None, 640, 128)    0           ['batch_normalization_104[0][0]']
#  )
#
#  re_lu_109 (ReLU)               (None, 640, 128)     0           ['max_pooling1d_32[0][0]']
#
#  conv1d_79 (Conv1D)             (None, 640, 64)      24576       ['re_lu_109[0][0]']
#
#  batch_normalization_105 (Batch  (None, 640, 64)     256         ['conv1d_79[0][0]']
#  Normalization)
#
#  re_lu_110 (ReLU)               (None, 640, 64)      0           ['batch_normalization_105[0][0]']
#
#  conv1d_80 (Conv1D)             (None, 640, 128)     8192        ['re_lu_110[0][0]']
#
#  batch_normalization_106 (Batch  (None, 640, 128)    512         ['conv1d_80[0][0]']
#  Normalization)
#
#  dropout_34 (Dropout)           (None, 640, 128)     0           ['batch_normalization_106[0][0]']
#
#  add_34 (Add)                   (None, 640, 128)     0           ['max_pooling1d_32[0][0]',
#                                                                   'dropout_34[0][0]']
#
#  re_lu_111 (ReLU)               (None, 640, 128)     0           ['add_34[0][0]']
#
#  conv1d_81 (Conv1D)             (None, 640, 64)      24576       ['re_lu_111[0][0]']
#
#  batch_normalization_107 (Batch  (None, 640, 64)     256         ['conv1d_81[0][0]']
#  Normalization)
#
#  re_lu_112 (ReLU)               (None, 640, 64)      0           ['batch_normalization_107[0][0]']
#
#  conv1d_82 (Conv1D)             (None, 640, 128)     8192        ['re_lu_112[0][0]']
#
#  batch_normalization_108 (Batch  (None, 640, 128)    512         ['conv1d_82[0][0]']
#  Normalization)
#
#  dropout_35 (Dropout)           (None, 640, 128)     0           ['batch_normalization_108[0][0]']
#
#  add_35 (Add)                   (None, 640, 128)     0           ['add_34[0][0]',
#                                                                   'dropout_35[0][0]']
#
#  re_lu_113 (ReLU)               (None, 640, 128)     0           ['add_35[0][0]']
#
#  conv1d_83 (Conv1D)             (None, 640, 64)      24576       ['re_lu_113[0][0]']
#
#  batch_normalization_109 (Batch  (None, 640, 64)     256         ['conv1d_83[0][0]']
#  Normalization)
#
#  re_lu_114 (ReLU)               (None, 640, 64)      0           ['batch_normalization_109[0][0]']
#
#  conv1d_84 (Conv1D)             (None, 640, 128)     8192        ['re_lu_114[0][0]']
#
#  batch_normalization_110 (Batch  (None, 640, 128)    512         ['conv1d_84[0][0]']
#  Normalization)
#
#  dropout_36 (Dropout)           (None, 640, 128)     0           ['batch_normalization_110[0][0]']
#
#  add_36 (Add)                   (None, 640, 128)     0           ['add_35[0][0]',
#                                                                   'dropout_36[0][0]']
#
#  re_lu_115 (ReLU)               (None, 640, 128)     0           ['add_36[0][0]']
#
#  conv1d_85 (Conv1D)             (None, 640, 64)      24576       ['re_lu_115[0][0]']
#
#  batch_normalization_111 (Batch  (None, 640, 64)     256         ['conv1d_85[0][0]']
#  Normalization)
#
#  re_lu_116 (ReLU)               (None, 640, 64)      0           ['batch_normalization_111[0][0]']
#
#  conv1d_86 (Conv1D)             (None, 640, 128)     8192        ['re_lu_116[0][0]']
#
#  batch_normalization_112 (Batch  (None, 640, 128)    512         ['conv1d_86[0][0]']
#  Normalization)
#
#  dropout_37 (Dropout)           (None, 640, 128)     0           ['batch_normalization_112[0][0]']
#
#  add_37 (Add)                   (None, 640, 128)     0           ['add_36[0][0]',
#                                                                   'dropout_37[0][0]']
#
#  re_lu_117 (ReLU)               (None, 640, 128)     0           ['add_37[0][0]']
#
#  conv1d_87 (Conv1D)             (None, 640, 64)      24576       ['re_lu_117[0][0]']
#
#  batch_normalization_113 (Batch  (None, 640, 64)     256         ['conv1d_87[0][0]']
#  Normalization)
#
#  re_lu_118 (ReLU)               (None, 640, 64)      0           ['batch_normalization_113[0][0]']
#
#  conv1d_88 (Conv1D)             (None, 640, 128)     8192        ['re_lu_118[0][0]']
#
#  batch_normalization_114 (Batch  (None, 640, 128)    512         ['conv1d_88[0][0]']
#  Normalization)
#
#  dropout_38 (Dropout)           (None, 640, 128)     0           ['batch_normalization_114[0][0]']
#
#  add_38 (Add)                   (None, 640, 128)     0           ['add_37[0][0]',
#                                                                   'dropout_38[0][0]']
#
#  re_lu_119 (ReLU)               (None, 640, 128)     0           ['add_38[0][0]']
#
#  conv1d_89 (Conv1D)             (None, 640, 64)      24576       ['re_lu_119[0][0]']
#
#  batch_normalization_115 (Batch  (None, 640, 64)     256         ['conv1d_89[0][0]']
#  Normalization)
#
#  re_lu_120 (ReLU)               (None, 640, 64)      0           ['batch_normalization_115[0][0]']
#
#  conv1d_90 (Conv1D)             (None, 640, 128)     8192        ['re_lu_120[0][0]']
#
#  batch_normalization_116 (Batch  (None, 640, 128)    512         ['conv1d_90[0][0]']
#  Normalization)
#
#  dropout_39 (Dropout)           (None, 640, 128)     0           ['batch_normalization_116[0][0]']
#
#  add_39 (Add)                   (None, 640, 128)     0           ['add_38[0][0]',
#                                                                   'dropout_39[0][0]']
#
#  re_lu_121 (ReLU)               (None, 640, 128)     0           ['add_39[0][0]']
#
#  conv1d_91 (Conv1D)             (None, 640, 64)      24576       ['re_lu_121[0][0]']
#
#  batch_normalization_117 (Batch  (None, 640, 64)     256         ['conv1d_91[0][0]']
#  Normalization)
#
#  re_lu_122 (ReLU)               (None, 640, 64)      0           ['batch_normalization_117[0][0]']
#
#  conv1d_92 (Conv1D)             (None, 640, 128)     8192        ['re_lu_122[0][0]']
#
#  batch_normalization_118 (Batch  (None, 640, 128)    512         ['conv1d_92[0][0]']
#  Normalization)
#
#  dropout_40 (Dropout)           (None, 640, 128)     0           ['batch_normalization_118[0][0]']
#
#  add_40 (Add)                   (None, 640, 128)     0           ['add_39[0][0]',
#                                                                   'dropout_40[0][0]']
#
#  re_lu_123 (ReLU)               (None, 640, 128)     0           ['add_40[0][0]']
#
#  conv1d_93 (Conv1D)             (None, 640, 64)      24576       ['re_lu_123[0][0]']
#
#  batch_normalization_119 (Batch  (None, 640, 64)     256         ['conv1d_93[0][0]']
#  Normalization)
#
#  re_lu_124 (ReLU)               (None, 640, 64)      0           ['batch_normalization_119[0][0]']
#
#  conv1d_94 (Conv1D)             (None, 640, 128)     8192        ['re_lu_124[0][0]']
#
#  batch_normalization_120 (Batch  (None, 640, 128)    512         ['conv1d_94[0][0]']
#  Normalization)
#
#  dropout_41 (Dropout)           (None, 640, 128)     0           ['batch_normalization_120[0][0]']
#
#  add_41 (Add)                   (None, 640, 128)     0           ['add_40[0][0]',
#                                                                   'dropout_41[0][0]']
#
#  re_lu_125 (ReLU)               (None, 640, 128)     0           ['add_41[0][0]']
#
#  conv1d_95 (Conv1D)             (None, 640, 64)      24576       ['re_lu_125[0][0]']
#
#  batch_normalization_121 (Batch  (None, 640, 64)     256         ['conv1d_95[0][0]']
#  Normalization)
#
#  re_lu_126 (ReLU)               (None, 640, 64)      0           ['batch_normalization_121[0][0]']
#
#  conv1d_96 (Conv1D)             (None, 640, 128)     8192        ['re_lu_126[0][0]']
#
#  batch_normalization_122 (Batch  (None, 640, 128)    512         ['conv1d_96[0][0]']
#  Normalization)
#
#  dropout_42 (Dropout)           (None, 640, 128)     0           ['batch_normalization_122[0][0]']
#
#  add_42 (Add)                   (None, 640, 128)     0           ['add_41[0][0]',
#                                                                   'dropout_42[0][0]']
#
#  re_lu_127 (ReLU)               (None, 640, 128)     0           ['add_42[0][0]']
#
#  conv1d_97 (Conv1D)             (None, 640, 64)      24576       ['re_lu_127[0][0]']
#
#  batch_normalization_123 (Batch  (None, 640, 64)     256         ['conv1d_97[0][0]']
#  Normalization)
#
#  re_lu_128 (ReLU)               (None, 640, 64)      0           ['batch_normalization_123[0][0]']
#
#  conv1d_98 (Conv1D)             (None, 640, 128)     8192        ['re_lu_128[0][0]']
#
#  batch_normalization_124 (Batch  (None, 640, 128)    512         ['conv1d_98[0][0]']
#  Normalization)
#
#  dropout_43 (Dropout)           (None, 640, 128)     0           ['batch_normalization_124[0][0]']
#
#  add_43 (Add)                   (None, 640, 128)     0           ['add_42[0][0]',
#                                                                   'dropout_43[0][0]']
#
#  re_lu_129 (ReLU)               (None, 640, 128)     0           ['add_43[0][0]']
#
#  conv1d_99 (Conv1D)             (None, 640, 64)      24576       ['re_lu_129[0][0]']
#
#  batch_normalization_125 (Batch  (None, 640, 64)     256         ['conv1d_99[0][0]']
#  Normalization)
#
#  re_lu_130 (ReLU)               (None, 640, 64)      0           ['batch_normalization_125[0][0]']
#
#  conv1d_100 (Conv1D)            (None, 640, 128)     8192        ['re_lu_130[0][0]']
#
#  batch_normalization_126 (Batch  (None, 640, 128)    512         ['conv1d_100[0][0]']
#  Normalization)
#
#  dropout_44 (Dropout)           (None, 640, 128)     0           ['batch_normalization_126[0][0]']
#
#  add_44 (Add)                   (None, 640, 128)     0           ['add_43[0][0]',
#                                                                   'dropout_44[0][0]']
#
#  re_lu_131 (ReLU)               (None, 640, 128)     0           ['add_44[0][0]']
#
#  conv1d_101 (Conv1D)            (None, 640, 80)      51200       ['re_lu_131[0][0]']
#
#  batch_normalization_127 (Batch  (None, 640, 80)     320         ['conv1d_101[0][0]']
#  Normalization)
#
#  re_lu_132 (ReLU)               (None, 640, 80)      0           ['batch_normalization_127[0][0]']
#
#  one_to_two_2 (OneToTwo)        (None, 640, 640, 80  0           ['re_lu_132[0][0]']
#                                 )
#
#  re_lu_133 (ReLU)               (None, 640, 640, 80  0           ['one_to_two_2[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 640, 640, 80  57600       ['re_lu_133[0][0]']
#                                 )
#
#  batch_normalization_128 (Batch  (None, 640, 640, 80  320        ['conv2d_26[0][0]']
#  Normalization)                 )
#
#  symmetrize2d_14 (Symmetrize2D)  (None, 640, 640, 80  0          ['batch_normalization_128[0][0]']
#                                 )
#
#  re_lu_134 (ReLU)               (None, 640, 640, 80  0           ['symmetrize2d_14[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 640, 640, 40  28800       ['re_lu_134[0][0]']
#                                 )
#
#  batch_normalization_129 (Batch  (None, 640, 640, 40  160        ['conv2d_27[0][0]']
#  Normalization)                 )
#
#  re_lu_135 (ReLU)               (None, 640, 640, 40  0           ['batch_normalization_129[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 640, 640, 80  3200        ['re_lu_135[0][0]']
#                                 )
#
#  batch_normalization_130 (Batch  (None, 640, 640, 80  320        ['conv2d_28[0][0]']
#  Normalization)                 )
#
#  dropout_45 (Dropout)           (None, 640, 640, 80  0           ['batch_normalization_130[0][0]']
#                                 )
#
#  add_45 (Add)                   (None, 640, 640, 80  0           ['symmetrize2d_14[0][0]',
#                                 )                                 'dropout_45[0][0]']
#
#  symmetrize2d_15 (Symmetrize2D)  (None, 640, 640, 80  0          ['add_45[0][0]']
#                                 )
#
#  re_lu_136 (ReLU)               (None, 640, 640, 80  0           ['symmetrize2d_15[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 640, 640, 40  28800       ['re_lu_136[0][0]']
#                                 )
#
#  batch_normalization_131 (Batch  (None, 640, 640, 40  160        ['conv2d_29[0][0]']
#  Normalization)                 )
#
#  re_lu_137 (ReLU)               (None, 640, 640, 40  0           ['batch_normalization_131[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 640, 640, 80  3200        ['re_lu_137[0][0]']
#                                 )
#
#  batch_normalization_132 (Batch  (None, 640, 640, 80  320        ['conv2d_30[0][0]']
#  Normalization)                 )
#
#  dropout_46 (Dropout)           (None, 640, 640, 80  0           ['batch_normalization_132[0][0]']
#                                 )
#
#  add_46 (Add)                   (None, 640, 640, 80  0           ['symmetrize2d_15[0][0]',
#                                 )                                 'dropout_46[0][0]']
#
#  symmetrize2d_16 (Symmetrize2D)  (None, 640, 640, 80  0          ['add_46[0][0]']
#                                 )
#
#  re_lu_138 (ReLU)               (None, 640, 640, 80  0           ['symmetrize2d_16[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 640, 640, 40  28800       ['re_lu_138[0][0]']
#                                 )
#
#  batch_normalization_133 (Batch  (None, 640, 640, 40  160        ['conv2d_31[0][0]']
#  Normalization)                 )
#
#  re_lu_139 (ReLU)               (None, 640, 640, 40  0           ['batch_normalization_133[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 640, 640, 80  3200        ['re_lu_139[0][0]']
#                                 )
#
#  batch_normalization_134 (Batch  (None, 640, 640, 80  320        ['conv2d_32[0][0]']
#  Normalization)                 )
#
#  dropout_47 (Dropout)           (None, 640, 640, 80  0           ['batch_normalization_134[0][0]']
#                                 )
#
#  add_47 (Add)                   (None, 640, 640, 80  0           ['symmetrize2d_16[0][0]',
#                                 )                                 'dropout_47[0][0]']
#
#  symmetrize2d_17 (Symmetrize2D)  (None, 640, 640, 80  0          ['add_47[0][0]']
#                                 )
#
#  re_lu_140 (ReLU)               (None, 640, 640, 80  0           ['symmetrize2d_17[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 640, 640, 40  28800       ['re_lu_140[0][0]']
#                                 )
#
#  batch_normalization_135 (Batch  (None, 640, 640, 40  160        ['conv2d_33[0][0]']
#  Normalization)                 )
#
#  re_lu_141 (ReLU)               (None, 640, 640, 40  0           ['batch_normalization_135[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 640, 640, 80  3200        ['re_lu_141[0][0]']
#                                 )
#
#  batch_normalization_136 (Batch  (None, 640, 640, 80  320        ['conv2d_34[0][0]']
#  Normalization)                 )
#
#  dropout_48 (Dropout)           (None, 640, 640, 80  0           ['batch_normalization_136[0][0]']
#                                 )
#
#  add_48 (Add)                   (None, 640, 640, 80  0           ['symmetrize2d_17[0][0]',
#                                 )                                 'dropout_48[0][0]']
#
#  symmetrize2d_18 (Symmetrize2D)  (None, 640, 640, 80  0          ['add_48[0][0]']
#                                 )
#
#  re_lu_142 (ReLU)               (None, 640, 640, 80  0           ['symmetrize2d_18[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 640, 640, 40  28800       ['re_lu_142[0][0]']
#                                 )
#
#  batch_normalization_137 (Batch  (None, 640, 640, 40  160        ['conv2d_35[0][0]']
#  Normalization)                 )
#
#  re_lu_143 (ReLU)               (None, 640, 640, 40  0           ['batch_normalization_137[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 640, 640, 80  3200        ['re_lu_143[0][0]']
#                                 )
#
#  batch_normalization_138 (Batch  (None, 640, 640, 80  320        ['conv2d_36[0][0]']
#  Normalization)                 )
#
#  dropout_49 (Dropout)           (None, 640, 640, 80  0           ['batch_normalization_138[0][0]']
#                                 )
#
#  add_49 (Add)                   (None, 640, 640, 80  0           ['symmetrize2d_18[0][0]',
#                                 )                                 'dropout_49[0][0]']
#
#  symmetrize2d_19 (Symmetrize2D)  (None, 640, 640, 80  0          ['add_49[0][0]']
#                                 )
#
#  re_lu_144 (ReLU)               (None, 640, 640, 80  0           ['symmetrize2d_19[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 640, 640, 40  28800       ['re_lu_144[0][0]']
#                                 )
#
#  batch_normalization_139 (Batch  (None, 640, 640, 40  160        ['conv2d_37[0][0]']
#  Normalization)                 )
#
#  re_lu_145 (ReLU)               (None, 640, 640, 40  0           ['batch_normalization_139[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 640, 640, 80  3200        ['re_lu_145[0][0]']
#                                 )
#
#  batch_normalization_140 (Batch  (None, 640, 640, 80  320        ['conv2d_38[0][0]']
#  Normalization)                 )
#
#  dropout_50 (Dropout)           (None, 640, 640, 80  0           ['batch_normalization_140[0][0]']
#                                 )
#
#  add_50 (Add)                   (None, 640, 640, 80  0           ['symmetrize2d_19[0][0]',
#                                 )                                 'dropout_50[0][0]']
#
#  symmetrize2d_20 (Symmetrize2D)  (None, 640, 640, 80  0          ['add_50[0][0]']
#                                 )
#
#  squeeze_excite_2 (SqueezeExcit  (None, 640, 640, 80  2010       ['symmetrize2d_20[0][0]']
#  e)                             )
#
#  cropping2d_2 (Cropping2D)      (None, 512, 512, 80  0           ['squeeze_excite_2[0][0]']
#                                 )
#
#  upper_tri_2 (UpperTri)         (None, 130305, 80)   0           ['cropping2d_2[0][0]']
#
#  re_lu_146 (ReLU)               (None, 130305, 80)   0           ['upper_tri_2[0][0]']
#
#  dense_4 (Dense)                (None, 130305, 5)    405         ['re_lu_146[0][0]']
#
#  switch_reverse_triu_4 (SwitchR  (None, 130305, 5)   0           ['dense_4[0][0]',
#  everseTriu)                                                      'stochastic_reverse_complement_2
#                                                                  [0][1]']
#
# ==================================================================================================
# Total params: 1,508,143
# Trainable params: 1,499,183
# Non-trainable params: 8,960
# __________________________________________________________________________________________________
# None
# model_strides [2048, 2048]
# target_lengths [130305, 130305]
# target_crops [-64833, -64833]
# built
# restored

# %%
hic_diags = params_model["diagonal_offset"]
try:
    target_crop = params_model["trunk"][-2]["cropping"]
except:
    target_crop = params_model["target_crop"]

print("hic_diags: ", hic_diags) 
print("target_crop: ", target_crop)
print("seq_length: ", seq_length)

target_length_cropped = int((seq_length//2048 - target_crop*2 - hic_diags) * ((seq_length//2048 - target_crop*2 - hic_diags) +1)/2) 
target_map_size = seq_length//2048  - target_crop*2 
triu_tup = np.triu_indices(target_map_size, 2)    # Return the indices for the upper-triangle of an (n, m) array, here k=2 (diagonal offset)
# target_map_size, target_length_cropped, triu_tup[0].shape

print("target_length_cropped: ", target_length_cropped)
print("target_map_size: ", target_map_size)
print("shape of triu_tup[0]: ", triu_tup[0].shape)
# Out:
# hic_diags:  2
# target_crop:  64
# seq_length:  1310720
# target_length_cropped:  130305
# target_map_size:  512
# shape of triu_tup[0]:  (130305,)

# %%
chrom = ["chr15", "chr18"]
start = [55300000, 65300000]
chunk = 1310720

# %%
for i in range(len(chrom)):
    if i == 0:
        human_frag = dna_io.dna_1hot(genome_open.fetch(chrom[i], start[i], start[i] + chunk).upper())
    else:
        new_frag =  dna_io.dna_1hot(genome_open.fetch(chrom[i], start[i], start[i] + chunk).upper())
        human_frag = np.stack((human_frag, new_frag), axis=0)

# %%
human_frag, human_frag.shape
# Out:
# (array([[[False, False, False,  True],
#          [ True, False, False, False],
#          [False, False,  True, False],
#          ...,
#          [ True, False, False, False],
#          [ True, False, False, False],
#          [ True, False, False, False]],
#
#         [[False, False, False,  True],
#          [False, False, False,  True],
#          [False, False, False,  True],
#          ...,
#          [False, False, False,  True],
#          [ True, False, False, False],
#          [False,  True, False, False]]]),
#  (2, 1310720, 4))

# %%
pred = seqnn_model.predict(human_frag)
                           # , batch_size=10)   # so 20/10 = 2 batches
# Out:
# 1/1 [==============================] - 14s 14s/step

# %%
targets = ["mESC", "mESC", "cortical neuron", "neocortex cortical neuron", "neural progenitor cell", "neocortex neural progenitor cell"]   #mouse
# targets = ["HFF", "H1hESC", "GM12878", "IMR90", "HCT116"]   #human

# %%
for j in range(pred.shape[-1]):
    plt.figure(figsize=(pred.shape[0]*6,pred.shape[-1]*5))
    target_ind = j
    vlim = .5
    bin_mid = target_map_size//2
    window = 50

    for i in range(len(pred)):
        insert_pred = pred[i]
        # print(i, np.sqrt( (insert_pred**2).sum(axis=0)))

        plt.subplot(6, 2, i+1)
        plt.axis("off")
        im = plt.matshow(
                from_upper_triu(  
                insert_pred[:,target_ind], target_map_size, hic_diags),
                vmin=-1*vlim, vmax=vlim, fignum=False, cmap="RdBu_r")
        plt.colorbar(im, fraction=0.046, pad=0.04)
        plt.title("scd: " + str(  np.sqrt( (insert_pred**2).sum(axis=0)  ).mean()) + "\n"
                 f"target: {targets[j]}")
            #plt.axis([ bin_mid  - window,bin_mid+window,bin_mid-window, bin_mid+window])
    plt.tight_layout()
    plt.show()

# %%
pred.shape
# Out:
# (2, 130305, 5)
