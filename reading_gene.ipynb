# %%
# !pip install bioframe
# Out:
# ...
#      |████████████████████████████████| 42 kB 14 kB/s eta 0:00:012
# ...

# %%
# !pip install gtfparse
# Out:
# ...
#   Created wheel for gtfparse: filename=gtfparse-1.2.1-py3-none-any.whl size=11637 sha256=5c63e0f8bcb4557d381264f5665b169ab94ab1a71c2448963daa9b58f5666734
#   Stored in directory: /home1/kadvani/.cache/pip/wheels/3c/99/0d/8f7f3dda491b2212eb6ab4bf815a7dd8bd5926e10de353820a
# Successfully built gtfparse
# ...

# %%
import bioframe
import gtfparse

# %%
# !pwd
# Out:
# /home1/kadvani

# %%
df = gtfparse.read_gtf(
    '3dfolding/mm9.refGene.gtf')
# Out:
# INFO:root:Extracted GTF attributes: ['gene_id', 'transcript_id', 'gene_name', 'exon_number', 'exon_id']

# %%
df
# Out:
#         seqname   source      feature     start       end  score strand frame  \
# 0         chr15  refGene   transcript  76909420  77137483    NaN      -     0
# 1         chr15  refGene         exon  76909420  76914636    NaN      -     0
# 2         chr15  refGene         3UTR  76909420  76914591    NaN      -     0
# 3         chr15  refGene          CDS  76914595  76914636    NaN      -     0
# 4         chr15  refGene         exon  76916008  76916080    NaN      -     0
# ...         ...      ...          ...       ...       ...    ...    ...   ...
# 1012735   chr19  refGene         5UTR  24268199  24268319    NaN      -     0
# 1012736   chr19  refGene         exon  24299341  24299516    NaN      -     0
# 1012737   chr19  refGene         5UTR  24299341  24299516    NaN      -     0
# 1012738   chr19  refGene  start_codon  24213311  24213313    NaN      -     0
# 1012739   chr19  refGene   stop_codon  24169915  24169917    NaN      -     0
#
# ...
